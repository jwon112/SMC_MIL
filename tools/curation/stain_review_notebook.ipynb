# %% [markdown]
# # WSI Stain Group Review
#
# This notebook reviews slides unresolved by filename rules. Each button click writes a row to `stain_slide_review.csv`.

# %%
from pathlib import Path
import sys

REPO_ROOT = Path('/home/jupyter/image_team/projects/SMC_MIL')
CURATION_ROOT = Path('/home/jupyter/data/image_team/labels/derived/wsi_curation_v3')
sys.path.insert(0, str(REPO_ROOT / 'tools' / 'curation'))

from stain_review_widget import launch_stain_review

editor = launch_stain_review(CURATION_ROOT, reviewer='')
