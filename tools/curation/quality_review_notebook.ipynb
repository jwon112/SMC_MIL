# %% [markdown]
# # WSI Quality Review
#
# Run the next cell. Every decision is written immediately to `quality_review_queue.csv`.

# %%
from pathlib import Path
import sys

REPO_ROOT = Path('/home/jupyter/image_team/projects/SMC_MIL')
CURATION_ROOT = Path('/home/jupyter/data/image_team/labels/derived/wsi_curation_v2')
sys.path.insert(0, str(REPO_ROOT / 'tools' / 'curation'))

from quality_review_widget import launch_quality_review

editor = launch_quality_review(CURATION_ROOT, reviewer='')
